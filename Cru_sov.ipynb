# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales_data_sample.csv", parse_dates=["ORDERDATE"],index_col="ORDERDATE")

# %%
df.head()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
#
#             QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# ORDERDATE
# 2003-02-24       1         2     2003  Motorcycles    95    S10_1678
# 2003-05-07       2         5     2003  Motorcycles    95    S10_1678
# 2003-07-01       3         7     2003  Motorcycles    95    S10_1678
# 2003-08-25       3         8     2003  Motorcycles    95    S10_1678
# 2003-10-10       4        10     2003  Motorcycles    95    S10_1678
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2823 entries, 2003-02-24 to 2005-05-06
# Data columns (total 18 columns):
# ORDERNUMBER        2823 non-null int64
# QUANTITYORDERED    2823 non-null int64
# PRICEEACH          2823 non-null float64
# ORDERLINENUMBER    2823 non-null int64
# SALES              2823 non-null float64
# QTR_ID             2823 non-null int64
# MONTH_ID           2823 non-null int64
# YEAR_ID            2823 non-null int64
# PRODUCTLINE        2823 non-null object
# MSRP               2823 non-null int64
# PRODUCTCODE        2823 non-null object
# CUSTOMERNAME       2823 non-null object
# Unnamed: 13        0 non-null float64
# CITY               2823 non-null object
# STATE              1337 non-null object
# COUNTRY            2823 non-null object
# TERRITORY          1749 non-null object
# DEALSIZE           2823 non-null object
# dtypes: float64(3), int64(7), object(8)
# memory usage: 419.0+ KB

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'Unnamed: 13', 'CITY', 'STATE',
#        'COUNTRY', 'TERRITORY', 'DEALSIZE'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt # basic plotting
# %matplotlib inline
import seaborn as sns # for prettier plots

# %%
df.plot(kind = "scatter", x = "MSRP", y= "QUANTITYORDERED")

# %%
plt.figure(figsize=(20, 10))
df.hist(alpha = 0.9)
plt.show()

# %%
plt.plot(df['ORDERNUMBER'], df['DEALSIZE'],color='g')

# %%
df['COUNTRY'].value_counts()
# Out:
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: COUNTRY, dtype: int64

# %%
df_USA = df[df['COUNTRY'] == 'USA']

# %%
df_USA
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2
# 2003-08-25        10145               45      83.26                6
# 2003-10-10        10159               49     100.00               14
# 2003-10-28        10168               36      96.66                1
# 2003-12-01        10201               22      98.57                2
# 2004-04-05        10237               23     100.00                7
# 2004-05-18        10251               28     100.00                2
# 2004-06-28        10263               34     100.00                2
# 2004-08-27        10285               36     100.00                6
# 2004-11-02        10318               46      94.74                1
# 2004-11-15        10329               42     100.00                1
# 2005-03-03        10388               42      76.36                4
# ...

# %%
plt.plot(df_USA['ORDERNUMBER'], df_USA['DEALSIZE'],color='g')

# %%
df_Ire = df[df['COUNTRY'] == 'Ireland']

# %%
df_Ire
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2004-02-12        10220               32     100.00                2  7181.44
# 2004-02-12        10220               30     100.00                3  4713.60
# 2004-02-12        10220               27     100.00                1  5045.22
# 2004-09-16        10297               25      82.79                4  2069.75
# 2004-02-12        10220               50     100.00                5  8258.00
# 2004-02-12        10220               26      56.07                8  1457.82
# 2004-09-16        10297               32     100.00                6  4061.76
# 2004-09-16        10297               32      65.51                1  2096.32
# 2004-02-12        10220               37     100.00                7  5032.74
# 2004-09-16        10297               23      72.45                5  1666.35
# 2004-09-16        10297               26     100.00                2  2856.88
# ...

# %%
plt.plot(df_Ire['ORDERNUMBER'], df_Ire['DEALSIZE'],color='g')

# %%
df['PRODUCTLINE'].value_counts()
# Out:
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: PRODUCTLINE, dtype: int64

# %%
df_tra = df[df['PRODUCTLINE'] == 'Trains']

# %%
df_tra
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-11        10105               38     100.00               13  4330.10
# 2003-04-16        10117               21      95.80                7  2011.80
# 2003-06-06        10128               41     100.00                4  4837.18
# 2003-08-08        10142               22      97.81               10  2151.82
# 2003-09-28        10153               29      88.74                9  2573.46
# 2003-10-22        10165               50     100.00                1  5344.50
# 2003-11-07        10177               29     100.00               11  3070.52
# 2003-11-14        10185               49      80.67               11  3952.83
# 2003-11-26        10196               35     100.00                3  3564.75
# 2004-01-02        10208               48     100.00               11  5614.56
# 2004-02-18        10221               23      80.67                5  1855.41
# ...

# %%
plt.plot(df_tra['COUNTRY'], df_tra['SALES'],color='g')

# %%
 sns.FacetGrid(df_USA, hue='PRODUCTLINE',height = 6) \
    .map(sns.kdeplot,'MONTH_ID').add_legend()

# %%
plt.figure()
df_USA.hist()
plt.show()

# %%
df_mot = df[df['PRODUCTLINE'] == 'Motorcycles']
df_mot
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
# 2003-10-28        10168               36      96.66                1  3479.76
# 2003-11-11        10180               29      86.13                9  2497.77
# 2003-11-18        10188               48     100.00                1  5512.32
# 2003-12-01        10201               22      98.57                2  2168.54
# 2004-01-15        10211               41     100.00               14  4708.44
# 2004-02-20        10223               37     100.00                1  3965.66
# ...

# %%
 sns.FacetGrid(df_mot, hue='PRODUCTLINE',height = 6) \
    .map(sns.kdeplot,'QUANTITYORDERED').add_legend()

# %%
df_mot.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'Unnamed: 13', 'CITY', 'STATE',
#        'COUNTRY', 'TERRITORY', 'DEALSIZE'],
#       dtype='object')

# %%
ts=df_mot.groupby(["YEAR_ID"])["SALES"].sum()
ts.astype('float')
plt.figure(figsize=(16,16))
plt.title('Total Sales of motorcycles')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.plot(ts);

# %%
df_mot.head(900)
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
# 2003-10-28        10168               36      96.66                1  3479.76
# 2003-11-11        10180               29      86.13                9  2497.77
# 2003-11-18        10188               48     100.00                1  5512.32
# 2003-12-01        10201               22      98.57                2  2168.54
# 2004-01-15        10211               41     100.00               14  4708.44
# 2004-02-20        10223               37     100.00                1  3965.66
# ...

# %%
df_mot['rol_M'] = df_mot['SALES'].rolling(10).mean()

df_tra['rol_M'] = df_tra['SALES'].rolling(10).mean()
df_tra['rol_M']
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ORDERDATE
# 2003-02-11         NaN
# 2003-04-16         NaN
# 2003-06-06         NaN
# 2003-08-08         NaN
# 2003-09-28         NaN
# 2003-10-22         NaN
# ...

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df_mot['rol_M'],label='Motorcycle')
plt.plot(df_tra['rol_M'],label='Trains')
#plt.plot(df_ship['rol_M'],label = 'Ships')

plt.legend(loc=2)

# %%
#df_tra.columns
df_tra_USA= df_tra[df_tra['COUNTRY'] == 'USA']

# %%
#very simple plotting
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_xlabel('YEAR_ID')
ax1.set_ylabel('rol_M')
ax1.set_title('Original Plot')
ax1.plot('YEAR_ID', 'rol_M', data = df_tra_USA);

# %%
ts
# Out:
# YEAR_ID
# 2003    370895.58
# 2004    560545.23
# 2005    234947.53
# Name: SALES, dtype: float64

# %%
ts_tra=df_tra.groupby(["YEAR_ID"])["SALES"].sum()
ts_tra
# Out:
# YEAR_ID
# 2003     72802.29
# 2004    116523.85
# 2005     36917.33
# Name: SALES, dtype: float64

# %%
df['PRODUCTLINE']
# Out:
# ORDERDATE
# 2003-02-24     Motorcycles
# 2003-05-07     Motorcycles
# 2003-07-01     Motorcycles
# 2003-08-25     Motorcycles
# 2003-10-10     Motorcycles
# 2003-10-28     Motorcycles
# 2003-11-11     Motorcycles
# 2003-11-18     Motorcycles
# 2003-12-01     Motorcycles
# 2004-01-15     Motorcycles
# 2004-02-20     Motorcycles
# 2004-04-05     Motorcycles
# 2004-05-18     Motorcycles
# 2004-06-28     Motorcycles
# 2004-07-23     Motorcycles
# 2004-08-27     Motorcycles
# 2004-09-30     Motorcycles
# 2004-10-15     Motorcycles
# 2004-11-02     Motorcycles
# 2004-11-15     Motorcycles
# 2004-11-24     Motorcycles
# 2004-12-17     Motorcycles
# 2005-02-03     Motorcycles
# 2005-03-03     Motorcycles
# 2005-04-08     Motorcycles
# 2005-05-13     Motorcycles
# 2003-01-29    Classic Cars
# 2003-03-24    Classic Cars
# 2003-05-28    Classic Cars
# 2003-07-24    Classic Cars
#                   ...
# 2005-03-01          Planes
# 2005-03-30          Planes
# 2005-04-01          Planes
# ...

# %%
df_ship = df[df['PRODUCTLINE'] == 'Ships']
df_ship
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-17        10106               41      83.44               18  3421.04
# 2003-04-28        10119               21      89.46                9  1878.66
# 2003-06-16        10130               40      96.34                2  3853.60
# 2003-08-10        10143               46      74.84               13  3442.64
# 2003-10-06        10155               44      79.14               11  3482.16
# 2003-10-23        10167               46      73.12                7  3363.52
# 2003-11-08        10178               41      81.72               10  3350.52
# 2003-11-14        10186               32      89.46                7  2862.72
# 2003-11-26        10197               46      87.74                4  4036.04
# 2004-01-09        10209               28     100.00                6  2817.92
# 2004-02-19        10222               49      94.62               10  4636.38
# ...

# %%
ts=df_ship.groupby(["YEAR_ID"])["SALES"].sum()
ts
# Out:
# YEAR_ID
# 2003    244821.09
# 2004    341437.97
# 2005    128178.07
# Name: SALES, dtype: float64

# %%
df_ship['rol_M'] = df_ship['SALES'].rolling(10).mean()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df_mot['rol_M'],label='Motorcycle')
plt.plot(df_tra['rol_M'],label='Trains')
plt.plot(df_ship['rol_M'],label = 'Ships')

plt.legend(loc=2)

# %%
df_tra.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'Unnamed: 13', 'CITY', 'STATE',
#        'COUNTRY', 'TERRITORY', 'DEALSIZE', 'rol_M'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df_mot['PRICEEACH'],label='Motorcycle')
plt.plot(df_tra['PRICEEACH'],label='Trains')
#plt.plot(df_ship['rol_M'],label = 'Ships')

plt.legend(loc=2)

# %%
ts=df_mot.groupby(["YEAR_ID"])["QUANTITYORDERED"].sum()
ts.astype('float')
plt.figure(figsize=(16,16))
plt.title('Total Sales of motorcycles')
plt.xlabel('Year')
plt.ylabel('Quantity')
plt.plot(ts);

# %%
df_mot
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
# 2003-10-28        10168               36      96.66                1  3479.76
# 2003-11-11        10180               29      86.13                9  2497.77
# 2003-11-18        10188               48     100.00                1  5512.32
# 2003-12-01        10201               22      98.57                2  2168.54
# 2004-01-15        10211               41     100.00               14  4708.44
# 2004-02-20        10223               37     100.00                1  3965.66
# ...

# %%
df.head()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
#
#             QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# ORDERDATE
# 2003-02-24       1         2     2003  Motorcycles    95    S10_1678
# 2003-05-07       2         5     2003  Motorcycles    95    S10_1678
# 2003-07-01       3         7     2003  Motorcycles    95    S10_1678
# 2003-08-25       3         8     2003  Motorcycles    95    S10_1678
# 2003-10-10       4        10     2003  Motorcycles    95    S10_1678
#
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2003-02-24', '2003-05-07', '2003-07-01', '2003-08-25',
#                '2003-10-10', '2003-10-28', '2003-11-11', '2003-11-18',
#                '2003-12-01', '2004-01-15',
#                ...
#                '2004-09-09', '2004-10-14', '2004-10-29', '2004-11-10',
#                '2004-11-21', '2004-12-02', '2005-01-31', '2005-03-01',
#                '2005-03-28', '2005-05-06'],
#               dtype='datetime64[ns]', name='ORDERDATE', length=2823, freq=None)

# %%
df_mot.head()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
#
#             QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# ORDERDATE
# 2003-02-24       1         2     2003  Motorcycles    95    S10_1678
# 2003-05-07       2         5     2003  Motorcycles    95    S10_1678
# 2003-07-01       3         7     2003  Motorcycles    95    S10_1678
# 2003-08-25       3         8     2003  Motorcycles    95    S10_1678
# 2003-10-10       4        10     2003  Motorcycles    95    S10_1678
#
# ...

# %%
df_mot['2003-11'].QUANTITYORDERED.mean()
# Out:
# 36.064516129032256

# %%
df_mot_03 = df_mot['2003-11']
df_mot_04 = df_mot['2004-11']
df_mot_04
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2004-11-02        10318               46      94.74                1  4358.04
# 2004-11-15        10329               42     100.00                1  4396.14
# 2004-11-24        10341               41     100.00                9  7737.93
# 2004-11-02        10318               45     100.00                4  5566.50
# 2004-11-15        10329               20     100.00                2  3176.00
# 2004-11-23        10339               40      68.92                4  2756.80
# 2004-11-02        10318               37     100.00                3  7667.14
# 2004-11-15        10329               26     100.00                3  5868.20
# 2004-11-23        10339               39      76.67                3  2990.13
# 2004-11-03        10319               30     100.00                9  4111.80
# 2004-11-15        10329               24     100.00                6  3542.64
# ...

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df_mot_03['rol_M'],label='2003')
plt.plot(df_mot_04['rol_M'],label='2004')
#plt.plot(df_ship['rol_M'],label = 'Ships')

plt.legend(loc=2)

# %%
df_mot_0304 = df_mot['2003-11-01':'2004-12-01']
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(df_mot_0304['rol_M'],label='2003 to 2004')
#plt.plot(df_mot_04['rol_M'],label='2004')
#plt.plot(df_ship['rol_M'],label = 'Ships')

plt.legend(loc=2)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'Unnamed: 13', 'CITY', 'STATE',
#        'COUNTRY', 'TERRITORY', 'DEALSIZE'],
#       dtype='object')

# %%
# monthly resampling on sales
df['SALES'].resample('M').mean().plot()

# %%
df['SALES'].resample('Q').mean().plot()

# %%
df['SALES'].resample('Y').mean().plot(kind = 'bar')

# %%
df['SALES'].plot(kind = 'bar')

# %%
 #df.sort_values(by='ORDERDATE') 
df.index
# Out:
# DatetimeIndex(['2003-02-24', '2003-05-07', '2003-07-01', '2003-08-25',
#                '2003-10-10', '2003-10-28', '2003-11-11', '2003-11-18',
#                '2003-12-01', '2004-01-15',
#                ...
#                '2004-09-09', '2004-10-14', '2004-10-29', '2004-11-10',
#                '2004-11-21', '2004-12-02', '2005-01-31', '2005-03-01',
#                '2005-03-28', '2005-05-06'],
#               dtype='datetime64[ns]', name='ORDERDATE', length=2823, freq=None)

# %%
df_mot_USA = df_mot[df_mot['COUNTRY']=='USA']
df_mot_USA['2003-02':'2003-12'].SALES.plot()

# %%
rng = pd.date_range(start="6/1/2016",end="6/30/2016",freq='B')
rng
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.dtypes
# Out:
# ORDERNUMBER          int64
# QUANTITYORDERED      int64
# PRICEEACH          float64
# ORDERLINENUMBER      int64
# SALES              float64
# QTR_ID               int64
# MONTH_ID             int64
# YEAR_ID              int64
# PRODUCTLINE         object
# MSRP                 int64
# PRODUCTCODE         object
# CUSTOMERNAME        object
# Unnamed: 13        float64
# CITY                object
# STATE               object
# COUNTRY             object
# TERRITORY           object
# DEALSIZE            object
# dtype: object

# %%
df.drop(columns=['QUANTITYORDERED', 'PRICEEACH'],inplace = True)

# %%
df.head()
# Out:
#             ORDERNUMBER  ORDERLINENUMBER    SALES  QTR_ID  MONTH_ID  YEAR_ID  \
# ORDERDATE
# 2003-02-24        10107                2  2871.00       1         2     2003
# 2003-05-07        10121                5  2765.90       2         5     2003
# 2003-07-01        10134                2  3884.34       3         7     2003
# 2003-08-25        10145                6  3746.70       3         8     2003
# 2003-10-10        10159               14  5205.27       4        10     2003
#
#             PRODUCTLINE  MSRP PRODUCTCODE              CUSTOMERNAME  \
# ORDERDATE
# 2003-02-24  Motorcycles    95    S10_1678         Land of Toys Inc.
# 2003-05-07  Motorcycles    95    S10_1678        Reims Collectables
# 2003-07-01  Motorcycles    95    S10_1678           Lyon Souveniers
# 2003-08-25  Motorcycles    95    S10_1678         Toys4GrownUps.com
# 2003-10-10  Motorcycles    95    S10_1678  Corporate Gift Ideas Co.
#
# ...

# %%
df.drop(columns=['Unnamed: 13','CITY','STATE','TERRITORY',],inplace = True)
df.drop(columns=['QUANTITYORDERED', 'PRICEEACH','ORDERNUMBER','ORDERLINENUMBER','QTR_ID','MONTH_ID','YEAR_ID','MSRP'],inplace = True)

# %%
df.head()
# Out:
#               SALES  PRODUCTLINE PRODUCTCODE              CUSTOMERNAME  \
# ORDERDATE
# 2003-02-24  2871.00  Motorcycles    S10_1678         Land of Toys Inc.
# 2003-05-07  2765.90  Motorcycles    S10_1678        Reims Collectables
# 2003-07-01  3884.34  Motorcycles    S10_1678           Lyon Souveniers
# 2003-08-25  3746.70  Motorcycles    S10_1678         Toys4GrownUps.com
# 2003-10-10  5205.27  Motorcycles    S10_1678  Corporate Gift Ideas Co.
#
#            COUNTRY DEALSIZE
# ORDERDATE
# 2003-02-24     USA    Small
# 2003-05-07  France    Small
# 2003-07-01  France   Medium
# 2003-08-25     USA   Medium
# 2003-10-10     USA   Medium
