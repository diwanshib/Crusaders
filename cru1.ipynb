# %%
import pandas as pd

# We'll also import seaborn, a Python graphing library
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="dark", color_codes=True)

# Next, we'll load the Iris flower dataset, which is in the "../input/" directory
df = pd.read_csv("sales_data_sample.csv") # the iris dataset is now a Pandas DataFrame

# Let's see what's in the iris data - Jupyter notebooks print the result of the last thing you do
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES       ORDERDATE  QTR_ID  MONTH_ID  \
# 0               30      95.70  2871.00  2/24/2003 0:00       1         2
# 1               34      81.35  2765.90   05-07-03 0:00       2         5
# 2               41      94.74  3884.34   07-01-03 0:00       3         7
# 3               45      83.26  3746.70  8/25/2003 0:00       3         8
# 4               49     100.00  5205.27   10-10-03 0:00       4        10
#
#    YEAR_ID  PRODUCTLINE              CUSTOMERNAME COUNTRY DEALSIZE
# 0     2003  Motorcycles         Land of Toys Inc.     USA    Small
# 1     2003  Motorcycles        Reims Collectables  France    Small
# 2     2003  Motorcycles           Lyon Souveniers  France   Medium
# 3     2003  Motorcycles         Toys4GrownUps.com     USA   Medium
# 4     2003  Motorcycles  Corporate Gift Ideas Co.     USA   Medium

# %%
df.shape
# Out:
# (2823, 11)

# %%
df_usa=df[df['COUNTRY']=="USA"]

# %%
df_usa.plot(kind='scatter', x='YEAR_ID', y='QUANTITYORDERED')

# %%
df_pm=df[df['PRODUCTLINE']=='Motorcycles']

# %%
sns.FacetGrid(df_pm, hue="COUNTRY", height=8) \
   .map(sns.kdeplot, "QUANTITYORDERED").add_legend()

# %%
sns.FacetGrid(df_pm, hue="PRODUCTLINE", height=7) \
   .map(plt.scatter, "MONTH_ID", "QUANTITYORDERED") \
   .add_legend()

# %%
sns.FacetGrid(df, hue="PRODUCTLINE", height=7) \
   .map(plt.scatter, "MONTH_ID", "QUANTITYORDERED") \
   .add_legend()

# %%
sns.FacetGrid(df_usa, hue="PRODUCTLINE", height=8) \
   .map(sns.kdeplot, "QUANTITYORDERED").add_legend()

# %%
df_pt=df[df['PRODUCTLINE']=='Trains']

# %%
sns.FacetGrid(df_pt, hue="COUNTRY", height=8) \
   .map(sns.kdeplot, "QUANTITYORDERED").add_legend()

# %%
df_uk=df[df['COUNTRY']=="UK"]

# %%
sns.FacetGrid(df_uk, hue="PRODUCTLINE", height=8) \
   .map(sns.kdeplot, "QUANTITYORDERED").add_legend()
